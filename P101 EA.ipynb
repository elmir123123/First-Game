# %%
#Adventure Game in Python
#by Elmir Alyrzae
"""
DocString:

Python Game 101

Lucky trip to Heaven!

You will create your character in a storyline that is designed to 
place you in uncomfortable situations, by the end of the game you 
will achieve greatness and gain new knowledge about the country you are
about to visit.

ENJOY)

Round 1: Guess & Beat
Round 2: Plane
Round 3: Arrival
Round 4: Lost
Round 5: Destiny

Known Bugs and/or Errors:
None.
"""

import time
import sys


def fail():
    print("Would you like to play again? (Yes/No)")
    replay = input().lower().strip()

    if replay == 'yes' or replay == "y":
        round_1()
    else:
        print(f"Thanks for playing {user_name}!")
        exit()


def round_1():
    global user_name
    global work_place
    global dream_place
    
    print("Welcome!")
    print("Would you like to play a little game?\n")
    yn = input().lower().strip()
    if yn.lower().strip() == "yes" or yn.lower().strip() == "y":
        print("Amazing!")

        time.sleep(0.5)
        print("Please state you name...\n")
        user_name = input()
        time.sleep(0.5)
        print("Which company do you work for?\n")
        work_place = input()
        time.sleep(0.5)
        print("Country you wanna visit overseas?\n")

        dream_place = input()
        time.sleep(0.5)
        print(
            f"{user_name}. Your boss has just announced that three employees at {work_place} will be paying a visit to your partners HQ overseas!!!\n")

        time.sleep(0.5)

        print(
            "Next week three lucky winner are announced and you are one of the lucky once to travel abroad for FREE!!!\n")

        print(
            "Your boss said that you will be going to one of the COOOOLEST places on planet earth. Guess where that is?\n")

        guess = input().lower().strip()
        country = ['russia']

        while guess in country:
            print ("BINGO!")
            round_2()
            break
        else:
            print(
                f"WRONG! {guess} was already prebooked for me and {dream_place} was also assiged to Jack. You'll be going to RUSSIA!\n")
        beat = input("Beat up Jack for being a Jack ASS?\n").lower().strip()

        if beat.lower().strip() == "yes" or beat.lower().strip() == "y":
            print(
                "Everybody is cheering for you! cause Jack is hate in the office! You get a bonus check but also you get fired!")
            fail()

        elif beat == "no" or beat == "n":
            print("""Seems like you done the right thing but now you are called a chicken!


                   ,~.
                ,-'__ `-,
               {,-'  `. }              ,')
              ,( a )   `-.__         ,',')~,
             <=.) (         `-.__,==' ' ' '}
               (   )                      /
                `-'\   ,                  )
                    |  \        `~.      /
                    \   `._        \    /
                     \     `._____,'   /
                      `-.            ,'
                         `-.      ,-'
                            `~~~~'
                            //_||
                         __//--'/`          
                       ,--'/`  '
                          '
""")
            round_2()
        else:
            fail()
    elif yn == "no" or yn == "n":
        print ("Let me know when you ready then")
        exit()
    else:
        print ("Invalid answer")
        fail()


def round_2():
    time.sleep(0.5)
    print(f"{user_name}, the next thing you know you are on a plane to THE CAPITAL OF MOTHER RUSSIA ... MOSCOW!")

    print("As soon as the plane takes off the guy right next to you gets out a glass bottle which seems like Vodka and starts celebrating his departure!")

    print('He gets so drunk and starts trying to talk you into drinking with him')

    choice = input("""
What are you going to do?

a) Politely reject his offer
b) Make up some excuse and try to find an empty seat to seat on
c) Drink with him\n""").lower().strip()

    if choice == "a" or choice == "a)" or choice == "politely reject his offer":
        print("He got mad and knocked you out! ☆(゜o°(○=(-_-;")
        fail()
    elif choice == "b" or choice == "b)" or choice == "find an empty seat":
        print(f"{user_name}, you are safe!")
        round_3()
    elif choice == "c" or choice == "c)" or choice == "drink":
        print("You get too drunk and think to yourself that it would be a good idea to take control of the plane and get the plane out of turbulance. On your way to the cockpit high turbulance persists, you jump up and hit your head on the cealing now you are daed (✖╭╮✖)\n")
        fail()
    else:
        print("Invalid answer! Please try again!")
        round_2()


def round_3():
    time.sleep(0.5)
    print(
        "you arrive to land in Moscow airport and as soon as collect your luggage 15 taxi drivers surround you, trying to get you in their car.")

    choice = input("""
What are you going to do?

a) Run away
b) Take the Cab
c) Call an Uber
""").lower().strip()

    if choice == "a" or choice == "a)" or choice == "Run away":
        print("The local TSA assumes that you are running with a bomb towards the crowd and shoot you")

        fail()
    elif choice == "b" or choice == "b)" or choice == "Take the Cab":
        print("Taxi driver drives you outside of the city and robs you, takes all your money and clothes, cause it is so cold you freeze to death")
        fail()
    elif choice == "c" or choice == "c)" or choice == "Call an Uber":
        print ("Your driver decides to take advantage of your unawarness and says that an alternative route is going to be faster drives you to the outskirts and robs you!")
        round_4()
    else:
        print("Invalid answer! Please try again!")
        exit()


def round_4():
    time.sleep(0.5)
    print("You are left without money and passport, not knowing where you are. What are your actions?")
    choice = input("""

a) Ask people for directions to the police station
b) Go to the embassy
c) Continue roaming the streets
""").lower().strip()

    if choice == "a" or choice == "a)":
        print("NEVER ASK A RUSSIAN FOR DIRECTIONS OR YOU WILL HAVE TO HAVE TO SUFFER")
        fail()
    elif choice == "b" or choice == "c)" or choice == "Go to the embassy":
        print("Embassy is closed and will not assist you until Monday")
        fail()
    elif choice == "c" or choice == "c)" or choice == "continue roaming the streets":
        print ("")
        round_5()
    else:
        print("Invalid answer! Please try again!")
        exit()


def round_5():
    time.sleep(0.5)
    correct_answer = ["a", "a)", "Agree"]
    print(
        "While roaming the streets of Moscow, you encounter one of your company's partner offices, your Russian colleagues find out what happened and decide to take good care of you.  \n  The next day they invited to a dinner party and the regional manager says that by the Russian traditions you must go with him to  \n  banay (Russian sauna). However, you are not a fan of hot places, especially the sauna, so you reject his offer. He is disappointed")

    choice = input("""

a) Agree to drink
b) Keep on being sober
c) Go to the hotel
""").lower().strip()

    while choice not in correct_answer:
        if choice == "b" or choice == "c)" or choice == "keep on being sober":
            print("Nobody enjoys your company, and you decide to leave, on your way to the hotel you get mugged and stabbed in the chest, you end up in the hospital, and this turned out to be an unsuccessful trip")
        elif choice == "c" or choice == "c)" or choice == "go to the hotel":
            print ("Your Russian counterparts got a terrible impression of you and sent a report that you did not act according to conduct so when you get back home you got fired")
        else:
            print("Invalid answer! Please try again!")
            exit()
        fail()
    else:
        print(f"""
        You forgot what happened last night but now that you woke
        up you notice that you are flying on a private jet the only 
        other passages on the plane introduces himself as an oligarch and 
        says that the two of you have got so wasted that you decided to rob 
        the Russian Central Bank and are now fleeing from the country on 
        his private jet heading to Uganda   
        
        
                ______
                _\ _~-\___
        =  = ==(____AA____D
                    \_____\___________________,-~~~~~~~`-.._
                    /     o O o o o o O O o o o o o o O o  |\_
                    `~-.__        ___..----..                  )
                          `---~~\___________/------------`````
                          =  ===(_________D

        
        
        
        
        
         _ __    __ _  _   _  ___   ___                
        | '_ \  / _` || | | |/ __| / _ \               
        | |_) || (_| || |_| |\__ \|  __/ _  _  _  _  _ 
        | .__/  \__,_| \__,_||___/ \___|(_)(_)(_)(_)(_)
        | |                                            
        |_|                                            
        
        
        
        
        
        
        \\\  ///     .-.      (o)__(o) 
        ((O)(O))   c(O_O)c    (__  __) 
         | \ ||   ,'.---.`,     (  )   
         ||\\||  / /|_|_|\ \     )(    
         || \ |  | \_____/ |    (  )   
         ||  ||  '. `---' .`     )/    
        (_/  \_)   `-...-'      (       
        
        
        
        the two of you are heading to {dream_place} to continue celebrating 
        your new position as the head of Russian office as the guy right 
        opposite you is your new CEO of {work_place} that he has just
        purchased and now you are living that
        
         _______   __    __   ______    ______   ______   ______   __    __       
        /       \ /  |  /  | /      \  /      \ /      | /      \ /  \  /  |      
        $$$$$$$  |$$ |  $$ |/$$$$$$  |/$$$$$$  |$$$$$$/ /$$$$$$  |$$  \ $$ |      
        $$ |__$$ |$$ |  $$ |$$ \__$$/ $$ \__$$/   $$ |  $$ |__$$ |$$$  \$$ |      
        $$    $$< $$ |  $$ |$$      \ $$      \   $$ |  $$    $$ |$$$$  $$ |      
        $$$$$$$  |$$ |  $$ | $$$$$$  | $$$$$$  |  $$ |  $$$$$$$$ |$$ $$ $$ |      
        $$ |  $$ |$$ \__$$ |/  \__$$ |/  \__$$ | _$$ |_ $$ |  $$ |$$ |$$$$ |      
        $$ |  $$ |$$    $$/ $$    $$/ $$    $$/ / $$   |$$ |  $$ |$$ | $$$ |      
        $_______/  _______   ________  $______  $__$$$/ $$__  $$/ $$__  __/ __    
        /       \ /       \ /        | /      \ /  \     /  |      /  |/  |/  |   
        $$$$$$$  |$$$$$$$  |$$$$$$$$/ /$$$$$$  |$$  \   /$$ |      $$ |$$ |$$ |   
        $$ |  $$ |$$ |__$$ |$$ |__    $$ |__$$ |$$$  \ /$$$ |      $$ |$$ |$$ |   
        $$ |  $$ |$$    $$< $$    |   $$    $$ |$$$$  /$$$$ |      $$ |$$ |$$ |   
        $$ |  $$ |$$$$$$$  |$$$$$/    $$$$$$$$ |$$ $$ $$/$$ |      $$/ $$/ $$/    
        $$ |__$$ |$$ |  $$ |$$ |_____ $$ |  $$ |$$ |$$$/ $$ |       __  __  __    
        $$    $$/ $$ |  $$ |$$       |$$ |  $$ |$$ | $/  $$ |      /  |/  |/  |   
        $$$$$$$/  $$/   $$/ $$$$$$$$/ $$/   $$/ $$/      $$/       $$/ $$/ $$/ 
        
        
        
        
        
        """)
        exit()


round_1()
